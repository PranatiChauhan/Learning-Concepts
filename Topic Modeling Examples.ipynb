# %% [markdown]
# This Notebook shows you how to perform topic modeling using LDA, NMF, and LSI.

# %%
import pandas as pd
df = pd.read_excel("../kevin/us_data_subset.xlsx") 
df.head()
# Out:
#                                                   TI  \
# 0  The Role of Business Intelligence and Communic...
# 1  OPERATIONAL IT FAILURES, IT VALUE DESTRUCTION,...
# 2  ON THE ROLE OF FAIRNESS AND SOCIAL DISTANCE IN...
# 3  KNOWLEDGE MANAGEMENT SYSTEM USE AND JOB PERFOR...
# 4  REPEATED INTERACTIONS VERSUS SOCIAL TIES: QUAN...
#
#                                                   AB  \
# 0  This study examines the role that business int...
# 1  This paper presents an empirical study of chan...
# 2  Online referral systems help firms attract new...
# 3  This paper seeks to develop a better understan...
# 4  The growing importance of online social networ...
#
#                                                   SO    PY
# 0  JOURNAL OF THE ASSOCIATION FOR INFORMATION SYS...  2017
# 1                                      MIS QUARTERLY  2017
# 2                                      MIS QUARTERLY  2017
# 3                                      MIS QUARTERLY  2017
# 4                                      MIS QUARTERLY  2017

# %%
#combine the title and abstract 
df['text'] = df['TI'] + ". " + df['AB'] #title followed by a period and then the abstractdf
df.head()
# Out:
#                                                   TI  \
# 0  The Role of Business Intelligence and Communic...
# 1  OPERATIONAL IT FAILURES, IT VALUE DESTRUCTION,...
# 2  ON THE ROLE OF FAIRNESS AND SOCIAL DISTANCE IN...
# 3  KNOWLEDGE MANAGEMENT SYSTEM USE AND JOB PERFOR...
# 4  REPEATED INTERACTIONS VERSUS SOCIAL TIES: QUAN...
#
#                                                   AB  \
# 0  This study examines the role that business int...
# 1  This paper presents an empirical study of chan...
# 2  Online referral systems help firms attract new...
# 3  This paper seeks to develop a better understan...
# 4  The growing importance of online social networ...
#
#                                                   SO    PY  \
# 0  JOURNAL OF THE ASSOCIATION FOR INFORMATION SYS...  2017
# 1                                      MIS QUARTERLY  2017
# 2                                      MIS QUARTERLY  2017
# 3                                      MIS QUARTERLY  2017
# 4                                      MIS QUARTERLY  2017
#
#                                                 text
# 0  The Role of Business Intelligence and Communic...
# 1  OPERATIONAL IT FAILURES, IT VALUE DESTRUCTION,...
# 2  ON THE ROLE OF FAIRNESS AND SOCIAL DISTANCE IN...
# 3  KNOWLEDGE MANAGEMENT SYSTEM USE AND JOB PERFOR...
# 4  REPEATED INTERACTIONS VERSUS SOCIAL TIES: QUAN...

# %%
df.isnull().sum() #check for null
# Out:
# TI      0
# AB      1
# SO      0
# PY      0
# text    1
# dtype: int64

# %%
#remove the null record from text
df.dropna(subset = ['text'], inplace = True)

# %%
df.shape
# Out:
# (2854, 5)

# %%
#preprocess data
import spacy
import re
from spacy.lang.en.stop_words import STOP_WORDS
stopword_list = list(STOP_WORDS)
nlp_en = spacy.load('en_core_web_lg')
def preprocess(txt):
    txt = txt.lower() #normalize text
    txt = re.sub(r'[^a-zA-Z]', ' ', txt)
    docs = nlp_en(txt)
    #lemmatize and remove stopwords
    word_list = [doc.lemma_ for doc in docs if doc.text 
                            not in stopword_list ]
    txt = " ".join(word_list)
    txt = txt.replace("-PRON-","")
    txt = txt.replace("PRON","")
    return txt

# %%
corpus = list(df['text'])
cleaned_corpus = [preprocess(txt) for txt in corpus]

# %%
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(min_df=10, max_df=0.9, 
                             stop_words='english', lowercase=True)
data_vectorized = vectorizer.fit_transform(cleaned_corpus)

# %%
#function to get topics and put them in dataframe columns - we pass an empty dataframe to it
def get_topics(model, vectorizer, model_name, df, top_n = 20):
        result = []
        for idx, topic in enumerate(model.components_):
            #print("Topic %d:" % (idx))
            topic_label = model_name + "_topic_" + str(idx)
            score = "SCORE_" + str(idx)
            aList = [(vectorizer.get_feature_names()[i], topic[i])
                            for i in topic.argsort()[:-top_n - 1:-1]]
            l1, l2 = zip(*aList)
            df[topic_label] = l1
            df[score] = l2

# %%
#Let us assume we have to get 20 topics --- use coherence or some other metric to determine optimum topics
n = 20

# %%
print("Working on " + str(n) + " topics .....")
df = pd.DataFrame()
# Build a Latent Dirichlet Allocation Model
print("LDA being performed ...")
lda_model = LatentDirichletAllocation(n_components=n, max_iter=5000, learning_method='online')
doc_topics = lda_model.fit_transform(data_vectorized)
print("Generating LDA Model .....")
get_topics(lda_model, vectorizer, "LDA", df) #populates the dataframe
#display the first 10 records of the dataframe
df.head(10)
# Out:
# Working on 20 topics .....
# LDA being performed ...
# Generating LDA Model .....
#   LDA_topic_0     SCORE_0      LDA_topic_1      SCORE_1  LDA_topic_2  \
# 0      health  316.211782          service  1279.646793       online
# 1    adoption  203.755454         customer   692.650189      product
# 2     patient  203.257760         platform   492.041782     consumer
# 3        care  163.149300         provider   282.547692       review
# 4  healthcare  149.812563          quality   134.885778          web
# 5    hospital  141.959444  personalization   130.026394       effect
# 6    capacity  137.225210              erp   121.146620      website
# 7       reuse  104.730569         resource    92.190965  information
# 8    delivery  104.325308        computing    92.069565      quality
# 9   physician   97.865877             base    90.305625         site
#
#        SCORE_2  LDA_topic_3     SCORE_3     LDA_topic_4     SCORE_4  ...  \
# 0  1055.046495     research  919.872726     information  836.531112  ...
# 1   919.853722  information  703.939482         digital  441.265733  ...
# 2   726.511794          new  599.011124      innovation  422.782872  ...
# 3   528.879920       theory  583.155996         privacy  415.923357  ...
# 4   431.314170         work  468.795813           study  255.333146  ...
# 5   420.038168   technology  428.557839    organization  247.503386  ...
# 6   319.329448     practice  421.626239          theory  237.537228  ...
# 7   315.891228          use  419.176357        research  228.271905  ...
# 8   294.127147        paper  362.132349  organizational  224.732810  ...
# 9   285.572712       change  348.061326          policy  223.438153  ...
#
#      LDA_topic_15    SCORE_15    LDA_topic_16    SCORE_16 LDA_topic_17  \
# 0  infrastructure  310.119522           trust  670.849261      project
# 1      governance  278.266962  recommendation  256.545535     decision
# 2      initiative  177.798606        commerce  238.825821      control
# 3        supplier  169.114108           agent  158.967136       option
# 4          return   99.279357            game  133.628069  flexibility
# 5           event   98.846774           study  111.415504   management
# 6          market   81.438555          online   98.250804         make
# 7    announcement   65.904768      electronic   94.740431      manager
# 8              ra   60.166796           human   78.693713         real
# 9   informational   39.483719          center   78.276841         goal
#
#       SCORE_17   LDA_topic_18     SCORE_18 LDA_topic_19    SCORE_19
# 0  1043.582836         social  1352.629815     security  489.072662
# 1   819.169268        network   948.095209         user  341.438946
# 2   417.652569      community   704.581548     internet  273.636199
# 3   195.328016         medium   498.771883       search  243.661221
# 4   152.645132         source   362.419679  advertising  235.342768
# 5   151.876933           open   313.554854       mobile  200.962228
# 6   149.117578         online   280.140726      content  174.972624
# 7   129.378238           user   262.138410       threat  159.710713
# 8   118.699910  participation   243.788059       effect  146.464131
# 9   102.770698            oss   196.904133          cue  135.633315
#
# [10 rows x 40 columns]

# %% [markdown]
# Note that the scores shown have to be normalized to get probabilities.

# %%
#Let us try non-negative matrix factorization
nmf_df = pd.DataFrame()
print("NMF being performed ....")
# Build a Non-Negative Matrix Factorization Model
nmf_model = NMF(n_components=n, max_iter=5000)
nmf_Z = nmf_model.fit_transform(data_vectorized)
   
print("Generating NMF Model ....")
get_topics(nmf_model, vectorizer, "NMF", nmf_df)
nmf_df.head()
# Out:
# NMF being performed ....
# Generating NMF Model ....
#   NMF_topic_0    SCORE_0 NMF_topic_1    SCORE_1  NMF_topic_2   SCORE_2  \
# 0         use  15.702796     product  10.859307         firm  9.503629
# 1       study   3.149416    consumer   4.551540  performance  2.220888
# 2      effect   2.519469      review   1.758293   capability  2.173323
# 3  individual   1.756827     quality   1.407722        value  1.149330
# 4      theory   1.637902      effect   0.994338   investment  1.086437
#
#     NMF_topic_3    SCORE_3  NMF_topic_4   SCORE_4  ... NMF_topic_15  SCORE_15  \
# 0   information  10.210022      project  9.878395  ...       online  8.375184
# 1       privacy   1.130997     software  4.852932  ...       review  3.621776
# 2      security   0.721607  development  3.024308  ...    community  3.115685
# 3  organization   0.527114      control  2.803027  ...     consumer  1.685983
# 4        supply   0.432534       source  1.286781  ...       effect  1.003725
#
#   NMF_topic_16   SCORE_16 NMF_topic_17  SCORE_17  NMF_topic_18  SCORE_18  \
# 0         user  12.021487         risk  6.457414         trust  8.485874
# 1     behavior   1.320081     decision  5.493375         study  2.001990
# 2     perceive   1.069223     security  2.469659      perceive  1.107102
# 3       effect   1.030635   investment  1.754728  relationship  1.071022
# 4      content   0.906786       factor  1.181523      commerce  0.884172
#
#   NMF_topic_19  SCORE_19
# 0       design  7.921679
# 1       theory  2.795955
# 2         base  1.207851
# 3     approach  1.140387
# 4      support  0.932231
#
# [5 rows x 40 columns]

# %%
lsi_df = pd.DataFrame()
print("LSI being performed ...")
# Build a Latent Semantic Indexing Model
lsi_model = TruncatedSVD(n_components=n, n_iter = 5000)
lsi_Z = lsi_model.fit_transform(data_vectorized)
    
print("Generating LSI Model .....")
get_topics(lsi_model, vectorizer, "LSI", lsi_df)
lsi_df.head()
# Out:
# LSI being performed ...
# Generating LSI Model .....
#    LSI_topic_0   SCORE_0 LSI_topic_1   SCORE_1  LSI_topic_2   SCORE_2  \
# 0  information  0.331270     product  0.474889         firm  0.566040
# 1     research  0.224602    consumer  0.304214   capability  0.183460
# 2        study  0.204003        firm  0.302815  performance  0.174968
# 3        model  0.194725      online  0.211117     business  0.151584
# 4   technology  0.177888      market  0.205440      project  0.127822
#
#    LSI_topic_3   SCORE_3  LSI_topic_4   SCORE_4  ... LSI_topic_15  SCORE_15  \
# 0  information  0.689237      product  0.381326  ...    community  0.358273
# 1     research  0.165567      project  0.362461  ...     software  0.258746
# 2      privacy  0.099086     software  0.191957  ...       online  0.228945
# 3     security  0.086015       review  0.162741  ...        model  0.217194
# 4     consumer  0.071696  information  0.160660  ...   innovation  0.158267
#
#   LSI_topic_16  SCORE_16 LSI_topic_17  SCORE_17 LSI_topic_18  SCORE_18  \
# 0          use  0.448408          use  0.266372        trust  0.472078
# 1     software  0.319437     business  0.230830      network  0.297500
# 2        study  0.164223       effect  0.207269     software  0.243792
# 3       effect  0.104423  performance  0.198176      process  0.174697
# 4      quality  0.091533       review  0.193236     business  0.172973
#
#   LSI_topic_19  SCORE_19
# 0     decision  0.386352
# 1     software  0.256153
# 2       review  0.244726
# 3      process  0.152546
# 4         risk  0.132635
#
# [5 rows x 40 columns]

# %% [markdown]
# Gensim is a very popular package for NLP tasks. Given below is an example of LDA using the Gensim package. Note that we don't have to explicitly vectorize the documents. Also, the corpus has to be a list of a list of words. The code has been adapted from the Gensim tutorials.

# %%
#Let us take a look at our cleaned corpus
cleaned_corpus[:2]
# Out:
# ['role business intelligence communication technology organizational agility   configurational approach   study examine role business intelligence   bi   communication technology play firm achieve organizational sensing agility   decision make agility   act agility different organizational environmental context   base information processing view organization dynamic capability theory   suggest configurational analytic framework depart standard linear paradigm examine s effect agility embed configuration organizational environmental element   line approach   use fuzzy set qualitative comparative analysis   fsqca   analyze field survey datum diverse industry   finding suggest equifinal pathway organizational agility specific boundary condition middle range theory determine role bi communication technology play organization   achieve organizational agility   discuss implication theory practice discuss future research avenue',
#  'operational failure   value destruction   board level governance change   paper present empirical study change firm implement board level governance   itg   experience operational failure   consistent separation oversight management decision   board level itg responsible monitor managerial decision policy control resource   expect operational failure indicate inadequacy board monitoring control resource result negative stock market reaction   turn   induce firm improve board level itg   expectation confirm base sample      operational failure u s   public financial firm   specifically   result demonstrate subsequent experience operational failure   firm improvement competency level board   improvement proportional degree negative market reaction     improvement executive board     increase experience internal   executive   director increase turnover rate cio serve board   furthermore   likelihood cio turnover low intensive firm turnover disruptive   result contribute understand critical connection operational failure board level itg']

# %%
#let us convert it to a list of a list of words
cleaned_corpus = [txt.split() for txt in cleaned_corpus]
cleaned_corpus[:2]
# Out:
# [['role',
#   'business',
#   'intelligence',
#   'communication',
#   'technology',
#   'organizational',
#   'agility',
#   'configurational',
#   'approach',
#   'study',
#   'examine',
#   'role',
#   'business',
#   'intelligence',
#   'bi',
#   'communication',
#   'technology',
#   'play',
#   'firm',
#   'achieve',
#   'organizational',
#   'sensing',
#   'agility',
#   'decision',
#   'make',
#   'agility',
#   'act',
#   'agility',
#   'different',
#   'organizational',
#   'environmental',
#   'context',
#   'base',
#   'information',
#   'processing',
#   'view',
#   'organization',
#   'dynamic',
#   'capability',
#   'theory',
#   'suggest',
#   'configurational',
#   'analytic',
#   'framework',
#   'depart',
#   'standard',
#   'linear',
#   'paradigm',
#   'examine',
#   's',
#   'effect',
#   'agility',
#   'embed',
#   'configuration',
#   'organizational',
#   'environmental',
#   'element',
#   'line',
#   'approach',
#   'use',
#   'fuzzy',
#   'set',
#   'qualitative',
#   'comparative',
#   'analysis',
#   'fsqca',
#   'analyze',
#   'field',
#   'survey',
#   'datum',
#   'diverse',
#   'industry',
#   'finding',
#   'suggest',
#   'equifinal',
#   'pathway',
#   'organizational',
#   'agility',
#   'specific',
#   'boundary',
#   'condition',
#   'middle',
#   'range',
#   'theory',
#   'determine',
#   'role',
#   'bi',
#   'communication',
#   'technology',
#   'play',
#   'organization',
#   'achieve',
#   'organizational',
#   'agility',
#   'discuss',
#   'implication',
#   'theory',
#   'practice',
#   'discuss',
#   'future',
#   'research',
#   'avenue'],
#  ['operational',
#   'failure',
#   'value',
#   'destruction',
#   'board',
#   'level',
#   'governance',
#   'change',
#   'paper',
#   'present',
#   'empirical',
#   'study',
#   'change',
#   'firm',
#   'implement',
#   'board',
#   'level',
#   'governance',
#   'itg',
#   'experience',
#   'operational',
#   'failure',
#   'consistent',
#   'separation',
#   'oversight',
#   'management',
#   'decision',
#   'board',
#   'level',
#   'itg',
#   'responsible',
#   'monitor',
#   'managerial',
#   'decision',
#   'policy',
#   'control',
#   'resource',
#   'expect',
#   'operational',
#   'failure',
#   'indicate',
#   'inadequacy',
#   'board',
#   'monitoring',
#   'control',
#   'resource',
#   'result',
#   'negative',
#   'stock',
#   'market',
#   'reaction',
#   'turn',
#   'induce',
#   'firm',
#   'improve',
#   'board',
#   'level',
#   'itg',
#   'expectation',
#   'confirm',
#   'base',
#   'sample',
#   'operational',
#   'failure',
#   'u',
#   's',
#   'public',
#   'financial',
#   'firm',
#   'specifically',
#   'result',
#   'demonstrate',
#   'subsequent',
#   'experience',
#   'operational',
#   'failure',
#   'firm',
#   'improvement',
#   'competency',
#   'level',
#   'board',
#   'improvement',
#   'proportional',
#   'degree',
#   'negative',
#   'market',
#   'reaction',
#   'improvement',
#   'executive',
#   'board',
#   'increase',
#   'experience',
#   'internal',
#   'executive',
#   'director',
#   'increase',
#   'turnover',
#   'rate',
#   'cio',
#   'serve',
#   'board',
#   'furthermore',
#   'likelihood',
#   'cio',
#   'turnover',
#   'low',
#   'intensive',
#   'firm',
#   'turnover',
#   'disruptive',
#   'result',
#   'contribute',
#   'understand',
#   'critical',
#   'connection',
#   'operational',
#   'failure',
#   'board',
#   'level',
#   'itg']]

# %%
# Remove rare and common tokens.
from gensim.corpora import Dictionary

# Create a dictionary representation of the documents.
dictionary = Dictionary(cleaned_corpus)

# Filter out words that occur less than 10 documents, or more than 80% of the documents.
dictionary.filter_extremes(no_below=10, no_above=0.8)

# %%
# Bag-of-words representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in cleaned_corpus]

# %%
# Train LDA model.
from gensim.models import LdaModel

# Set training parameters.
num_topics = 20
chunksize = 3000
passes = 20
iterations = 5000
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# Make a index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)

# %%
top_topics = model.top_topics(corpus) #, num_words=20)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# Average topic coherence: -2.1325.
# [([(0.035534427, 'research'),
#    (0.029536864, 'design'),
#    (0.017161876, 'system'),
#    (0.014146009, 'approach'),
#    (0.013011451, 'information'),
#    (0.010492493, 'framework'),
#    (0.010143331, 'method'),
#    (0.01012634, 'theory'),
#    (0.009775196, 'paper'),
#    (0.009470124, 'model'),
#    (0.009407007, 'decision'),
#    (0.008342261, 'base'),
#    (0.007372736, 'process'),
#    (0.007258637, 'problem'),
#    (0.0070692794, 'propose'),
#    (0.0066523, 'provide'),
#    (0.0064737415, 'develop'),
#    (0.0060670474, 'science'),
#    (0.0057143676, 'analysis'),
#    (0.0055991714, 'study')],
#   -1.3313410118493487),
#  ([(0.031094925, 'system'),
#    (0.022595163, 'use'),
#    (0.021588111, 'knowledge'),
#    (0.01676294, 'research'),
#    (0.016703313, 'information'),
#    (0.014610848, 'theory'),
#    (0.01171822, 'user'),
#    (0.010414423, 'work'),
#    (0.009563938, 'idea'),
#    (0.009200944, 'organizational'),
#    (0.008331014, 'study'),
#    (0.008191933, 'support'),
#    (0.008168371, 'community'),
#    (0.0076484596, 'organization'),
#    (0.007641288, 'process'),
#    (0.0074089207, 'technology'),
#    (0.0072528035, 'individual'),
#    (0.006573958, 'paper'),
#    (0.006534276, 'base'),
#    (0.006428752, 'new')],
#   -1.3352979491027244),
#  ([(0.022939522, 'user'),
#    (0.022317091, 'technology'),
#    (0.01887044, 'use'),
#    (0.018445052, 'model'),
#    (0.015843742, 'study'),
#    (0.015057452, 'behavior'),
#    (0.013396088, 'perceive'),
#    (0.011840698, 'social'),
#    (0.011773163, 'influence'),
#    (0.011739821, 'research'),
#    (0.010833979, 'effect'),
#    (0.010690308, 'intention'),
#    (0.0091641415, 'individual'),
#    (0.008954561, 'result'),
#    (0.008841706, 'theory'),
#    (0.008687962, 'information'),
#    (0.008290674, 'adoption'),
#    (0.0074325493, 'usage'),
#    (0.00733558, 'test'),
#    (0.007104461, 'relationship')],
#   -1.3930890112051566),
#  ([(0.041287858, 'firm'),
#    (0.028720547, 'market'),
#    (0.015192489, 'investment'),
#    (0.013147122, 'industry'),
#    (0.013039533, 'cost'),
#    (0.012160185, 'effect'),
#    (0.011305009, 'value'),
#    (0.011278501, 'product'),
#    (0.010776179, 'model'),
#    (0.010748515, 'high'),
#    (0.010577185, 's'),
#    (0.010045437, 'competition'),
#    (0.009697143, 'strategy'),
#    (0.009696011, 'increase'),
#    (0.0096271075, 'price'),
#    (0.009404182, 'find'),
#    (0.00820326, 'technology'),
#    (0.0075459555, 'result'),
#    (0.0072396034, 'low'),
#    (0.006945226, 'profit')],
#   -1.3942367733541867),
#  ([(0.02053118, 'innovation'),
#    (0.017641995, 'research'),
#    (0.016905185, 'information'),
#    (0.015959626, 'model'),
#    (0.014334535, 'construct'),
#    (0.011448197, 'study'),
#    (0.0108189415, 'measure'),
#    (0.010204732, 'system'),
#    (0.009509359, 'business'),
#    (0.009436647, 'measurement'),
#    (0.0090807, 'process'),
#    (0.00865104, 'technology'),
#    (0.0083215395, 'analysis'),
#    (0.008170742, 'new'),
#    (0.007789271, 'group'),
#    (0.0065280884, 'base'),
#    (0.006416779, 'use'),
#    (0.0063896757, 'modeling'),
#    (0.0062457887, 'paper'),
#    (0.006232322, 'result')],
#   -1.4205289679045312),
#  ([(0.030168533, 'firm'),
#    (0.025526168, 'capability'),
#    (0.024077373, 'performance'),
#    (0.02092985, 'information'),
#    (0.019088965, 'technology'),
#    (0.017524976, 'business'),
#    (0.01577989, 'organizational'),
#    (0.012930333, 'resource'),
#    (0.012502815, 's'),
#    (0.012197219, 'management'),
#    (0.011856563, 'alignment'),
#    (0.011785244, 'strategic'),
#    (0.011036378, 'study'),
#    (0.0094065685, 'organization'),
#    (0.0083679985, 'relationship'),
#    (0.0081988145, 'competitive'),
#    (0.008073219, 'value'),
#    (0.007744792, 'system'),
#    (0.007657745, 'effect'),
#    (0.007320802, 'level')],
#   -1.432009656034154),
#  ([(0.047730416, 'digital'),
#    (0.023908762, 'research'),
#    (0.020836687, 'infrastructure'),
#    (0.018519314, 'technology'),
#    (0.016802711, 'collaboration'),
#    (0.015541558, 'information'),
#    (0.011817103, 'boundary'),
#    (0.011140136, 'strategy'),
#    (0.011047078, 'business'),
#    (0.011026724, 'platform'),
#    (0.010510626, 'organization'),
#    (0.009520622, 'practice'),
#    (0.008574143, 'new'),
#    (0.008021779, 'process'),
#    (0.0071727163, 'paper'),
#    (0.0071188645, 'study'),
#    (0.007103043, 'system'),
#    (0.0070440783, 'field'),
#    (0.007026106, 'develop'),
#    (0.0063309674, 'emerge')],
#   -1.5010780404707513),
#  ([(0.01618729, 'network'),
#    (0.016083227, 'communication'),
#    (0.01441532, 'research'),
#    (0.013766499, 'system'),
#    (0.013765508, 'analysis'),
#    (0.013704359, 'datum'),
#    (0.013378368, 'study'),
#    (0.01337314, 'method'),
#    (0.013212424, 'journal'),
#    (0.011327693, 'approach'),
#    (0.01065305, 'information'),
#    (0.010362627, 'bias'),
#    (0.008655225, 'data'),
#    (0.008491693, 'structure'),
#    (0.0077704466, 'base'),
#    (0.007604767, 'result'),
#    (0.0061257263, 'social'),
#    (0.0060657514, 'provide'),
#    (0.0059368894, 'set'),
#    (0.0057718866, 'technique')],
#   -1.6905909779093597),
#  ([(0.04601593, 'consumer'),
#    (0.026185712, 'product'),
#    (0.023399144, 'web'),
#    (0.02257107, 'e'),
#    (0.020947495, 'commerce'),
#    (0.016559329, 'information'),
#    (0.015412555, 'channel'),
#    (0.015304055, 'trust'),
#    (0.013959756, 'site'),
#    (0.011705906, 'online'),
#    (0.011003999, 'retailer'),
#    (0.010819057, 'good'),
#    (0.010335382, 'strategy'),
#    (0.009000944, 'price'),
#    (0.008795089, 'customer'),
#    (0.0084023895, 'model'),
#    (0.007890841, 'decision'),
#    (0.007417688, 'internet'),
#    (0.007290061, 'electronic'),
#    (0.007071042, 'base')],
#   -1.7641362573753554),
#  ([(0.054616548, 'team'),
#    (0.05308729, 'knowledge'),
#    (0.027362144, 'virtual'),
#    (0.019998228, 'member'),
#    (0.013754504, 'task'),
#    (0.0132082235, 'performance'),
#    (0.012208431, 'share'),
#    (0.011827468, 'study'),
#    (0.010569835, 'process'),
#    (0.010024702, 'individual'),
#    (0.009460493, 'work'),
#    (0.0091913175, 'group'),
#    (0.008894697, 'social'),
#    (0.008873674, 'effect'),
#    (0.008513288, 'capital'),
#    (0.008479248, 'collaborative'),
#    (0.008049672, 'information'),
#    (0.007414422, 'collaboration'),
#    (0.0073962105, 'project'),
#    (0.007290554, 'level')],
#   -1.7728618995808967),
#  ([(0.03748327, 'risk'),
#    (0.03209063, 'project'),
#    (0.022945818, 'security'),
#    (0.020776493, 'model'),
#    (0.020065663, 'information'),
#    (0.0140013, 'datum'),
#    (0.012565869, 'system'),
#    (0.011239006, 'decision'),
#    (0.009463983, 'result'),
#    (0.008556773, 'performance'),
#    (0.008193406, 'study'),
#    (0.0073088207, 'management'),
#    (0.0066372743, 'response'),
#    (0.0064073913, 'cost'),
#    (0.0063609704, 'factor'),
#    (0.006216473, 'base'),
#    (0.005968432, 'manager'),
#    (0.005854599, 'increase'),
#    (0.0056397174, 'privacy'),
#    (0.005318286, 'detection')],
#   -1.9521604928853882),
#  ([(0.020885607, 'information'),
#    (0.01780902, 'privacy'),
#    (0.017367905, 'seller'),
#    (0.015729157, 'app'),
#    (0.013075706, 'user'),
#    (0.012108171, 'buyer'),
#    (0.01204974, 'mobile'),
#    (0.011578533, 'effect'),
#    (0.0102233365, 'market'),
#    (0.00865819, 'level'),
#    (0.008220191, 'find'),
#    (0.008190012, 'piracy'),
#    (0.008133366, 's'),
#    (0.0072909477, 'model'),
#    (0.0070312372, 'datum'),
#    (0.0068830773, 'time'),
#    (0.006706207, 'high'),
#    (0.0064573213, 'use'),
#    (0.006290717, 'policy'),
#    (0.0062761228, 'result')],
#   -2.0204344571788577),
#  ([(0.026672028, 'process'),
#    (0.017637705, 'information'),
#    (0.01663727, 'outsourcing'),
#    (0.016437298, 'firm'),
#    (0.01538348, 'software'),
#    (0.015297178, 'contract'),
#    (0.014926168, 'source'),
#    (0.014603008, 'supply'),
#    (0.014347613, 'chain'),
#    (0.012953913, 'vendor'),
#    (0.012844678, 'client'),
#    (0.012586939, 'business'),
#    (0.0121146, 'governance'),
#    (0.011978808, 'integration'),
#    (0.011347852, 'relationship'),
#    (0.011096788, 'value'),
#    (0.0109665515, 'performance'),
#    (0.010669699, 'supplier'),
#    (0.010005626, 'development'),
#    (0.009267284, 'study')],
#   -2.0710410774430734),
#  ([(0.040850077, 'online'),
#    (0.028655719, 'product'),
#    (0.022310538, 'social'),
#    (0.019461408, 'review'),
#    (0.015929257, 'effect'),
#    (0.015822308, 'user'),
#    (0.0151321525, 'consumer'),
#    (0.011985938, 'content'),
#    (0.011646842, 'community'),
#    (0.010006226, 'medium'),
#    (0.009616319, 'information'),
#    (0.008409042, 'study'),
#    (0.008114832, 'quality'),
#    (0.007615401, 'website'),
#    (0.0075778654, 'result'),
#    (0.007503775, 'rating'),
#    (0.0069513484, 'purchase'),
#    (0.006032535, 'sale'),
#    (0.006023688, 'recommendation'),
#    (0.005975334, 'search')],
#   -2.0729881651918287),
#  ([(0.031480588, 'system'),
#    (0.029048394, 'software'),
#    (0.019987414, 'information'),
#    (0.017147347, 'theory'),
#    (0.015556501, 'research'),
#    (0.0144714415, 'development'),
#    (0.013461256, 'study'),
#    (0.013443385, 'trust'),
#    (0.010838874, 'implementation'),
#    (0.00859622, 'security'),
#    (0.008509441, 'organization'),
#    (0.008257275, 'practice'),
#    (0.00804137, 'job'),
#    (0.0069609582, 'work'),
#    (0.006571466, 'organizational'),
#    (0.0065613533, 'requirement'),
#    (0.0065460633, 'policy'),
#    (0.0060422975, 'literature'),
#    (0.0060184407, 'professional'),
#    (0.005798371, 'process')],
#   -2.087057106105318),
#  ([(0.060947992, 'network'),
#    (0.018910095, 'adoption'),
#    (0.014990871, 'standard'),
#    (0.014359761, 'peer'),
#    (0.014056454, 'project'),
#    (0.01355759, 'developer'),
#    (0.013553248, 'model'),
#    (0.013255924, 'platform'),
#    (0.010716842, 'learning'),
#    (0.010504624, 'development'),
#    (0.010489615, 'influence'),
#    (0.009956863, 'control'),
#    (0.009112536, 'user'),
#    (0.008960962, 'diffusion'),
#    (0.008886486, 'p'),
#    (0.00819756, 'innovation'),
#    (0.0079896, 'effect'),
#    (0.0073329513, 'study'),
#    (0.0070859757, 'technology'),
#    (0.006989295, 'system')],
#   -2.1248139831577446),
#  ([(0.14206167, 'service'),
#    (0.055024672, 'customer'),
#    (0.029031716, 'provider'),
#    (0.025332341, 'quality'),
#    (0.014106283, 'content'),
#    (0.011388441, 'medium'),
#    (0.01067788, 'user'),
#    (0.010089052, 'engagement'),
#    (0.008029561, 'study'),
#    (0.007779415, 'ra'),
#    (0.007614841, 'design'),
#    (0.0075924285, 'platform'),
#    (0.007405494, 'online'),
#    (0.0072881663, 'trade'),
#    (0.0071022, 'perceive'),
#    (0.0065517225, 'result'),
#    (0.006458775, 'decision'),
#    (0.0064441436, 'game'),
#    (0.0064273705, 'e'),
#    (0.006415441, 'delivery')],
#   -2.727726002182904),
#  ([(0.037901554, 'auction'),
#    (0.03002974, 'price'),
#    (0.016454272, 'country'),
#    (0.014459556, 'bid'),
#    (0.013345643, 'government'),
#    (0.013184452, 'bidder'),
#    (0.012292792, 'internet'),
#    (0.012238971, 'e'),
#    (0.0102216, 'online'),
#    (0.009549522, 'mechanism'),
#    (0.009119376, 'market'),
#    (0.008933088, 'strategy'),
#    (0.00785453, 'bidding'),
#    (0.0069663716, 'time'),
#    (0.006825518, 'buyer'),
#    (0.0065226876, 'datum'),
#    (0.006435562, 'economic'),
#    (0.0062050484, 'find'),
#    (0.006122315, 'offshore'),
#    (0.0061087334, 'model')],
#   -3.1848992668140754),
#  ([(0.033061884, 'health'),
#    (0.021316074, 'oss'),
#    (0.020682773, 'patient'),
#    (0.018631672, 'community'),
#    (0.01613615, 'care'),
#    (0.01595732, 'open'),
#    (0.015186399, 'hospital'),
#    (0.014904802, 'healthcare'),
#    (0.014185249, 'information'),
#    (0.013132365, 'source'),
#    (0.011848169, 'resource'),
#    (0.011698677, 'project'),
#    (0.011635122, 'control'),
#    (0.009732832, 'network'),
#    (0.009680139, 'medical'),
#    (0.0076356223, 'software'),
#    (0.007630993, 'base'),
#    (0.0074337134, 'social'),
#    (0.0073556295, 'physician'),
#    (0.0072698887, 'pricing')],
#   -3.790371185632718),
#  ([(0.024429012, 'option'),
#    (0.023261888, 'information'),
#    (0.017532464, 'investment'),
#    (0.015597293, 'learning'),
#    (0.014813104, 's'),
#    (0.012619111, 'technology'),
#    (0.012004624, 'training'),
#    (0.01019398, 'outsource'),
#    (0.009991591, 'real'),
#    (0.008617969, 'student'),
#    (0.00807232, 'cio'),
#    (0.007950759, 'base'),
#    (0.0075334506, 'study'),
#    (0.0072804186, 'public'),
#    (0.0071362485, 'decision'),
#    (0.006851295, 'investor'),
#    (0.00680109, 'crowdfunding'),
#    (0.0066604773, 'control'),
#    (0.0066328663, 'learn'),
#    (0.0057966444, 'venture')],
#   -5.58328687129177)]

# %%
for i in range(20):
    print("Topic: " + str(i + 1) + ":")
    a, b = zip(*top_topics[i][0])
    for w in b:
        print(w, end=', ')
    print("\n")
# Out:
# Topic: 1:
# research, design, system, approach, information, framework, method, theory, paper, model, decision, base, process, problem, propose, provide, develop, science, analysis, study,
#
# Topic: 2:
# system, use, knowledge, research, information, theory, user, work, idea, organizational, study, support, community, organization, process, technology, individual, paper, base, new,
#
# Topic: 3:
# user, technology, use, model, study, behavior, perceive, social, influence, research, effect, intention, individual, result, theory, information, adoption, usage, test, relationship,
#
# Topic: 4:
# firm, market, investment, industry, cost, effect, value, product, model, high, s, competition, strategy, increase, price, find, technology, result, low, profit,
#
# Topic: 5:
# innovation, research, information, model, construct, study, measure, system, business, measurement, process, technology, analysis, new, group, base, use, modeling, paper, result,
#
# Topic: 6:
# firm, capability, performance, information, technology, business, organizational, resource, s, management, alignment, strategic, study, organization, relationship, competitive, value, system, effect, level,
#
# Topic: 7:
# digital, research, infrastructure, technology, collaboration, information, boundary, strategy, business, platform, organization, practice, new, process, paper, study, system, field, develop, emerge,
#
# Topic: 8:
# network, communication, research, system, analysis, datum, study, method, journal, approach, information, bias, data, structure, base, result, social, provide, set, technique,
#
# Topic: 9:
# consumer, product, web, e, commerce, information, channel, trust, site, online, retailer, good, strategy, price, customer, model, decision, internet, electronic, base,
#
# Topic: 10:
# team, knowledge, virtual, member, task, performance, share, study, process, individual, work, group, social, effect, capital, collaborative, information, collaboration, project, level,
#
# Topic: 11:
# risk, project, security, model, information, datum, system, decision, result, performance, study, management, response, cost, factor, base, manager, increase, privacy, detection,
#
# Topic: 12:
# information, privacy, seller, app, user, buyer, mobile, effect, market, level, find, piracy, s, model, datum, time, high, use, policy, result,
#
# Topic: 13:
# process, information, outsourcing, firm, software, contract, source, supply, chain, vendor, client, business, governance, integration, relationship, value, performance, supplier, development, study,
#
# Topic: 14:
# online, product, social, review, effect, user, consumer, content, community, medium, information, study, quality, website, result, rating, purchase, sale, recommendation, search,
#
# Topic: 15:
# system, software, information, theory, research, development, study, trust, implementation, security, organization, practice, job, work, organizational, requirement, policy, literature, professional, process,
#
# Topic: 16:
# network, adoption, standard, peer, project, developer, model, platform, learning, development, influence, control, user, diffusion, p, innovation, effect, study, technology, system,
#
# Topic: 17:
# service, customer, provider, quality, content, medium, user, engagement, study, ra, design, platform, online, trade, perceive, result, decision, game, e, delivery,
#
# Topic: 18:
# auction, price, country, bid, government, bidder, internet, e, online, mechanism, market, strategy, bidding, time, buyer, datum, economic, find, offshore, model,
#
# Topic: 19:
# health, oss, patient, community, care, open, hospital, healthcare, information, source, resource, project, control, network, medical, software, base, social, physician, pricing,
#
# Topic: 20:
# option, information, investment, learning, s, technology, training, outsource, real, student, cio, base, study, public, decision, investor, crowdfunding, control, learn, venture,
